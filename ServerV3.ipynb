# %%
import numpy as np
import binascii

# %%
def text_to_bits(text, encoding='utf-8', errors='surrogatepass'):
    bits = bin(int(binascii.hexlify(text.encode(encoding, errors)), 16))[2:]
    return bits.zfill(8 * ((len(bits) + 7) // 8))

def text_from_bits(bits, encoding='utf-8', errors='surrogatepass'):
    n = int(bits, 2)
    return int2bytes(n).decode(encoding, errors)

def int2bytes(i):
    hex_string = '%x' % i
    n = len(hex_string)
    return binascii.unhexlify(hex_string.zfill(n + (n & 1)))

def string2bits(s=''):
    return [bin(ord(x))[2:].zfill(8) for x in s]

def bits2string(b=None):
    return ''.join([chr(int(x, 2)) for x in b])

# %%
def decimalToBinary(num , places):
    return ('{0:0' +  str(places) + 'b}').format(num)


def binaryToDecimal(binary):
    return int(binary, 2)
        
def xorBinary(binary,key = "00000000"):
    i=0
    encBin = ""
    while(i<8):
        if(binary[i] == '0' and key[i] == '0') or (binary[i] == '1' and key[i] == '1'):
            encBin+="0"
        else:
            encBin+="1"
        i+=1
        
#     print(binary , key , encBin)    
    return encBin
    
def compressBinary(binary):
    i=0
    compressBin = ""
    while(i<8):
        if(i%2 == 0):
            if((binary[i] == '0' and binary[i+1] == '0') or (binary[i] == '1' and binary[i+1] == '1')):
                compressBin+="0"
            else:
                compressBin+="1"
        i+=1
        
    return compressBin

def to_twoscomplement(bits, value):
    if value < 0:
        value = ( 1<<bits ) + value
    formatstring = '{:0%ib}' % bits
    return formatstring.format(value)

# %% [markdown]
# # Code for decoding

# %%
import sys, traceback
import time , socket
import struct

# %%
def server_program():
    # get the hostname
    host = '192.168.43.153'
    port = 5000  # initiate port no above 1024
    count = 0
    current = 0
    currentByte = ''
    last = 0
    org_data = []
    start_time = None
    end_time = None

    
    server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)  # get instance
    server_socket.bind((host, port))  # bind host address and port together
    server_socket.listen(1)

    try :
        connection,client_address = server_socket.accept()
        while True:
            data = connection.recv(1)
            if not data:
                end_time = int(time.time() * 1000)
                print("Time in MS :" , end_time - start_time)
                print("Packet Transfered :" , count)
                connection.close()
                server_socket.close()
                return count , (end_time - start_time)
            
            data = decimalToBinary(int.from_bytes(data, byteorder='little'), 8)
            if data[0] == '0':
                if last == 0:
                    start_time = int(time.time() * 1000)
                count+=1
                current+=1
                currentByte+=data[1:]
                if current == 3:
                    dataPoint = int(currentByte[1:],2)
                    if currentByte[0] == '1':
                        dataPoint *= -1
                    org_data.append(dataPoint)
                    last=dataPoint
                    current = 0
                    currentByte = ''
                    
            else:
                count+=1
                dataPoint = int(data[2:],2)
                if data[1]=='1':
                    dataPoint*=-1
                dataPoint+=last
                org_data.append(dataPoint)
                last = dataPoint
        
    except Exception:
        print("Some Error Occured")
        traceback.print_exc()
        connection.close()
        server_socket.close()

# %%
cdata = server_program()
# Out:
# Time in MS : 2710
# Packet Transfered : 980117

# %%
di = {}

for i in range(125):
    packets, ttime = server_program()
    if(di.get(packets)) :
        di[packets].append(ttime)
    else :
        di[packets] = [ttime]
    time.sleep(3)
# Out:
# Time in MS : 2615
# Packet Transfered : 980117
# Time in MS : 2706
# Packet Transfered : 980117
# Time in MS : 2583
# Packet Transfered : 980117
# Time in MS : 2633
# Packet Transfered : 980117
# Time in MS : 2675
# Packet Transfered : 980117
# Time in MS : 2679
# Packet Transfered : 980117
# Time in MS : 2651
# Packet Transfered : 980117
# Time in MS : 2568
# Packet Transfered : 980117
# Time in MS : 2634
# Packet Transfered : 980117
# Time in MS : 2611
# Packet Transfered : 980117
# Time in MS : 2647
# Packet Transfered : 980117
# Time in MS : 2666
# Packet Transfered : 980117
# Time in MS : 2552
# Packet Transfered : 980117
# Time in MS : 2641
# Packet Transfered : 980117
# Time in MS : 2586
# Packet Transfered : 980117
# Time in MS : 2648
# Packet Transfered : 980117
# Time in MS : 2634
# Packet Transfered : 980117
# Time in MS : 2747
# Packet Transfered : 980117
# Time in MS : 2621
# Packet Transfered : 980117
# Time in MS : 2642
# Packet Transfered : 980117
# Time in MS : 2610
# Packet Transfered : 980117
# Time in MS : 2639
# Packet Transfered : 980117
# Time in MS : 2560
# Packet Transfered : 980117
# Time in MS : 2585
# Packet Transfered : 980117
# Time in MS : 2582
# Packet Transfered : 980117
# Time in MS : 1432
# Packet Transfered : 490058
# Time in MS : 1388
# Packet Transfered : 490058
# Time in MS : 1358
# Packet Transfered : 490058
# Time in MS : 1358
# Packet Transfered : 490058
# Time in MS : 1368
# Packet Transfered : 490058
# Time in MS : 1335
# Packet Transfered : 490058
# Time in MS : 1393
# Packet Transfered : 490058
# Time in MS : 1362
# Packet Transfered : 490058
# Time in MS : 1362
# Packet Transfered : 490058
# Time in MS : 1376
# Packet Transfered : 490058
# Time in MS : 1367
# Packet Transfered : 490058
# Time in MS : 1419
# Packet Transfered : 490058
# Time in MS : 1402
# Packet Transfered : 490058
# Time in MS : 1397
# Packet Transfered : 490058
# Time in MS : 1385
# Packet Transfered : 490058
# Time in MS : 1340
# Packet Transfered : 490058
# Time in MS : 1399
# Packet Transfered : 490058
# Time in MS : 1345
# Packet Transfered : 490058
# Time in MS : 1362
# Packet Transfered : 490058
# Time in MS : 1450
# Packet Transfered : 490058
# Time in MS : 1352
# Packet Transfered : 490058
# Time in MS : 1341
# Packet Transfered : 490058
# Time in MS : 1384
# Packet Transfered : 490058
# Time in MS : 1334
# Packet Transfered : 490058
# Time in MS : 1364
# Packet Transfered : 490058
# Time in MS : 728
# Packet Transfered : 245029
# Time in MS : 709
# Packet Transfered : 245029
# Time in MS : 703
# Packet Transfered : 245029
# Time in MS : 737
# Packet Transfered : 245029
# Time in MS : 726
# Packet Transfered : 245029
# Time in MS : 744
# Packet Transfered : 245029
# Time in MS : 711
# Packet Transfered : 245029
# Time in MS : 688
# Packet Transfered : 245029
# Time in MS : 728
# Packet Transfered : 245029
# Time in MS : 848
# Packet Transfered : 245029
# Time in MS : 711
# Packet Transfered : 245029
# Time in MS : 691
# Packet Transfered : 245029
# Time in MS : 703
# Packet Transfered : 245029
# Time in MS : 692
# Packet Transfered : 245029
# Time in MS : 727
# Packet Transfered : 245029
# Time in MS : 724
# Packet Transfered : 245029
# Time in MS : 693
# Packet Transfered : 245029
# Time in MS : 722
# Packet Transfered : 245029
# Time in MS : 773
# Packet Transfered : 245029
# Time in MS : 701
# Packet Transfered : 245029
# Time in MS : 744
# Packet Transfered : 245029
# Time in MS : 710
# Packet Transfered : 245029
# Time in MS : 703
# Packet Transfered : 245029
# Time in MS : 716
# Packet Transfered : 245029
# Time in MS : 855
# Packet Transfered : 245029
# Time in MS : 396
# Packet Transfered : 122514
# Time in MS : 466
# Packet Transfered : 122514
# Time in MS : 383
# Packet Transfered : 122514
# Time in MS : 475
# Packet Transfered : 122514
# Time in MS : 420
# Packet Transfered : 122514
# Time in MS : 401
# Packet Transfered : 122514
# Time in MS : 363
# Packet Transfered : 122514
# Time in MS : 392
# Packet Transfered : 122514
# Time in MS : 383
# Packet Transfered : 122514
# Time in MS : 365
# Packet Transfered : 122514
# Time in MS : 364
# Packet Transfered : 122514
# Time in MS : 387
# Packet Transfered : 122514
# Time in MS : 396
# Packet Transfered : 122514
# Time in MS : 350
# Packet Transfered : 122514
# Time in MS : 385
# Packet Transfered : 122514
# Time in MS : 485
# Packet Transfered : 122514
# Time in MS : 439
# Packet Transfered : 122514
# Time in MS : 361
# Packet Transfered : 122514
# Time in MS : 393
# Packet Transfered : 122514
# Time in MS : 421
# Packet Transfered : 122514
# Time in MS : 401
# Packet Transfered : 122514
# Time in MS : 402
# Packet Transfered : 122514
# Time in MS : 384
# Packet Transfered : 122514
# Time in MS : 382
# Packet Transfered : 122514
# Time in MS : 458
# Packet Transfered : 122514
# Time in MS : 233
# Packet Transfered : 61257
# Time in MS : 203
# Packet Transfered : 61257
# Time in MS : 198
# Packet Transfered : 61257
# Time in MS : 219
# Packet Transfered : 61257
# Time in MS : 210
# Packet Transfered : 61257
# Time in MS : 211
# Packet Transfered : 61257
# Time in MS : 200
# Packet Transfered : 61257
# Time in MS : 218
# Packet Transfered : 61257
# Time in MS : 193
# Packet Transfered : 61257
# Time in MS : 198
# Packet Transfered : 61257
# Time in MS : 281
# Packet Transfered : 61257
# Time in MS : 197
# Packet Transfered : 61257
# Time in MS : 202
# Packet Transfered : 61257
# Time in MS : 220
# Packet Transfered : 61257
# Time in MS : 198
# Packet Transfered : 61257
# Time in MS : 325
# Packet Transfered : 61257
# Time in MS : 202
# Packet Transfered : 61257
# Time in MS : 193
# Packet Transfered : 61257
# Time in MS : 179
# Packet Transfered : 61257
# Time in MS : 205
# Packet Transfered : 61257
# Time in MS : 197
# Packet Transfered : 61257
# Time in MS : 201
# Packet Transfered : 61257
# Time in MS : 209
# Packet Transfered : 61257
# Time in MS : 202
# Packet Transfered : 61257
# Time in MS : 234
# Packet Transfered : 61257

# %% [markdown]
# # Code for Un-compressed

# %%
def UC_server_program():
    # get the hostname
    host = '192.168.43.153'
    port = 5000  # initiate port no above 1024
    count = 0
    current = 0
    start = 0
    currentByte = ''
    org_data = []
    start_time = None
    end_time = None

    
    server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)  # get instance
    server_socket.bind((host, port))  # bind host address and port together
    server_socket.listen(1)

    try :
        connection,client_address = server_socket.accept()
        while True:
            data = connection.recv(1)
            if not data:
                end_time = int(time.time() * 1000)
                print("Time in MS :" , end_time - start_time)
                print("Packet Transfered :" , count)
                connection.close()
                server_socket.close()
                return count , (end_time - start_time)
            
            else:
                if start == 0:
                    start_time = int(time.time() * 1000)
                    start = 1
                count+=1
                current += 1
                data = decimalToBinary(int.from_bytes(data, byteorder='little'),8)
                currentByte+=data
                if current == 3:
                    dataPoint = int(currentByte[1:],2)
                    if currentByte[0] == '1':
                        dataPoint *= -1
                    org_data.append(dataPoint)
                    current = 0
                    currentByte = ''

    except Exception:
        print("Some Error Occured")
        traceback.print_exc()
        connection.close()
        server_socket.close()

# %%
cdata = UC_server_program()
# Out:
# Time in MS : 6703
# Packet Transfered : 2786973

# %%
di = {}

for i in range(125):
    packets, ttime = UC_server_program()
    if(di.get(packets)) :
        di[packets].append(ttime)
    else :
        di[packets] = [ttime]
    time.sleep(3)
# Out:
# Time in MS : 6692
# Packet Transfered : 2786973
# Time in MS : 6664
# Packet Transfered : 2786973
# Time in MS : 6604
# Packet Transfered : 2786973
# Time in MS : 7041
# Packet Transfered : 2786973
# Time in MS : 6655
# Packet Transfered : 2786973
# Time in MS : 6545
# Packet Transfered : 2786973
# Time in MS : 6890
# Packet Transfered : 2786973
# Time in MS : 6513
# Packet Transfered : 2786973
# Time in MS : 6880
# Packet Transfered : 2786973
# Time in MS : 6680
# Packet Transfered : 2786973
# Time in MS : 6821
# Packet Transfered : 2786973
# Time in MS : 6812
# Packet Transfered : 2786973
# Time in MS : 6805
# Packet Transfered : 2786973
# Time in MS : 6635
# Packet Transfered : 2786973
# Time in MS : 6669
# Packet Transfered : 2786973
# Time in MS : 6753
# Packet Transfered : 2786973
# Time in MS : 6769
# Packet Transfered : 2786973
# Time in MS : 6722
# Packet Transfered : 2786973
# Time in MS : 6416
# Packet Transfered : 2786973
# Time in MS : 6654
# Packet Transfered : 2786973
# Time in MS : 6684
# Packet Transfered : 2786973
# Time in MS : 6669
# Packet Transfered : 2786973
# Time in MS : 6663
# Packet Transfered : 2786973
# Time in MS : 6625
# Packet Transfered : 2786973
# Time in MS : 6823
# Packet Transfered : 2786973
# Time in MS : 3397
# Packet Transfered : 1393486
# Time in MS : 3384
# Packet Transfered : 1393486
# Time in MS : 3315
# Packet Transfered : 1393486
# Time in MS : 3439
# Packet Transfered : 1393486
# Time in MS : 3363
# Packet Transfered : 1393486
# Time in MS : 3322
# Packet Transfered : 1393486
# Time in MS : 3325
# Packet Transfered : 1393486
# Time in MS : 3364
# Packet Transfered : 1393486
# Time in MS : 3525
# Packet Transfered : 1393486
# Time in MS : 3402
# Packet Transfered : 1393486
# Time in MS : 3420
# Packet Transfered : 1393486
# Time in MS : 3464
# Packet Transfered : 1393486
# Time in MS : 3435
# Packet Transfered : 1393486
# Time in MS : 3386
# Packet Transfered : 1393486
# Time in MS : 3451
# Packet Transfered : 1393486
# Time in MS : 3540
# Packet Transfered : 1393486
# Time in MS : 3472
# Packet Transfered : 1393486
# Time in MS : 3457
# Packet Transfered : 1393486
# Time in MS : 3411
# Packet Transfered : 1393486
# Time in MS : 3524
# Packet Transfered : 1393486
# Time in MS : 3579
# Packet Transfered : 1393486
# Time in MS : 3485
# Packet Transfered : 1393486
# Time in MS : 3415
# Packet Transfered : 1393486
# Time in MS : 3459
# Packet Transfered : 1393486
# Time in MS : 3531
# Packet Transfered : 1393486
# Time in MS : 1771
# Packet Transfered : 696743
# Time in MS : 1799
# Packet Transfered : 696743
# Time in MS : 1830
# Packet Transfered : 696743
# Time in MS : 1843
# Packet Transfered : 696743
# Time in MS : 1838
# Packet Transfered : 696743
# Time in MS : 1800
# Packet Transfered : 696743
# Time in MS : 1759
# Packet Transfered : 696743
# Time in MS : 1806
# Packet Transfered : 696743
# Time in MS : 1872
# Packet Transfered : 696743
# Time in MS : 1774
# Packet Transfered : 696743
# Time in MS : 1850
# Packet Transfered : 696743
# Time in MS : 1793
# Packet Transfered : 696743
# Time in MS : 1812
# Packet Transfered : 696743
# Time in MS : 1812
# Packet Transfered : 696743
# Time in MS : 1925
# Packet Transfered : 696743
# Time in MS : 1804
# Packet Transfered : 696743
# Time in MS : 1804
# Packet Transfered : 696743
# Time in MS : 2194
# Packet Transfered : 696743
# Time in MS : 1806
# Packet Transfered : 696743
# Time in MS : 1802
# Packet Transfered : 696743
# Time in MS : 1786
# Packet Transfered : 696743
# Time in MS : 1787
# Packet Transfered : 696743
# Time in MS : 1768
# Packet Transfered : 696743
# Time in MS : 1846
# Packet Transfered : 696743
# Time in MS : 1752
# Packet Transfered : 696743
# Time in MS : 907
# Packet Transfered : 348371
# Time in MS : 940
# Packet Transfered : 348371
# Time in MS : 953
# Packet Transfered : 348371
# Time in MS : 935
# Packet Transfered : 348371
# Time in MS : 925
# Packet Transfered : 348371
# Time in MS : 900
# Packet Transfered : 348371
# Time in MS : 935
# Packet Transfered : 348371
# Time in MS : 957
# Packet Transfered : 348371
# Time in MS : 943
# Packet Transfered : 348371
# Time in MS : 932
# Packet Transfered : 348371
# Time in MS : 981
# Packet Transfered : 348371
# Time in MS : 937
# Packet Transfered : 348371
# Time in MS : 932
# Packet Transfered : 348371
# Time in MS : 922
# Packet Transfered : 348371
# Time in MS : 968
# Packet Transfered : 348371
# Time in MS : 914
# Packet Transfered : 348371
# Time in MS : 941
# Packet Transfered : 348371
# Time in MS : 920
# Packet Transfered : 348371
# Time in MS : 925
# Packet Transfered : 348371
# Time in MS : 942
# Packet Transfered : 348371
# Time in MS : 905
# Packet Transfered : 348371
# Time in MS : 933
# Packet Transfered : 348371
# Time in MS : 949
# Packet Transfered : 348371
# Time in MS : 939
# Packet Transfered : 348371
# Time in MS : 935
# Packet Transfered : 348371
# Time in MS : 522
# Packet Transfered : 174185
# Time in MS : 484
# Packet Transfered : 174185
# Time in MS : 482
# Packet Transfered : 174185
# Time in MS : 497
# Packet Transfered : 174185
# Time in MS : 507
# Packet Transfered : 174185
# Time in MS : 500
# Packet Transfered : 174185
# Time in MS : 481
# Packet Transfered : 174185
# Time in MS : 514
# Packet Transfered : 174185
# Time in MS : 523
# Packet Transfered : 174185
# Time in MS : 505
# Packet Transfered : 174185
# Time in MS : 509
# Packet Transfered : 174185
# Time in MS : 513
# Packet Transfered : 174185
# Time in MS : 505
# Packet Transfered : 174185
# Time in MS : 526
# Packet Transfered : 174185
# Time in MS : 512
# Packet Transfered : 174185
# Time in MS : 475
# Packet Transfered : 174185
# Time in MS : 507
# Packet Transfered : 174185
# Time in MS : 517
# Packet Transfered : 174185
# Time in MS : 469
# Packet Transfered : 174185
# Time in MS : 496
# Packet Transfered : 174185
# Time in MS : 488
# Packet Transfered : 174185
# Time in MS : 485
# Packet Transfered : 174185
# Time in MS : 565
# Packet Transfered : 174185
# Time in MS : 493
# Packet Transfered : 174185
# Time in MS : 497
# Packet Transfered : 174185
